# %% [markdown]
# <a href="https://colab.research.google.com/github/goswamipayal/Technocolabs-Internship-Mini-Project/blob/main/PayalG_Step_By_Step_DataPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
warnings.filterwarnings('ignore')

# %%
company = pd.read_csv("/content/companies.csv")
company
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        NaN
# 1         c:10             1     Company         10        NaN
# 2        c:100             2     Company        100        NaN
# 3      c:10000             3     Company      10000        NaN
# 4      c:10001             4     Company      10001        NaN
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        NaN
# 6028  c:139006          6028     Company     139006        NaN
# 6029  c:139007          6029     Company     139007        NaN
# 6030  c:139008          6030     Company     139008        NaN
# 6031  c:139009          6031     Company     139009        NaN
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                 NaN                            NaN
#
#         category_code     status  ... first_milestone_at last_milestone_at  \
# 0                 web  operating  ...           9/5/2010         9/18/2013
# 1         games_video   acquired  ...                NaN               NaN
# 2         games_video   acquired  ...           2/1/2003         9/23/2011
# 3     network_hosting  operating  ...                NaN               NaN
# 4         games_video  operating  ...                NaN               NaN
# ...               ...        ...  ...                ...               ...
# 6027        ecommerce  operating  ...                NaN               NaN
# 6028           mobile  operating  ...           2/1/2013          2/1/2013
# 6029       consulting  operating  ...                NaN               NaN
# 6030              web  operating  ...                NaN               NaN
# 6031              NaN        NaN  ...                NaN               NaN
#
#      milestones relationships             created_by        created_at  \
# 0           5.0          17.0       initial-importer    5/25/2007 6:51
# 1           NaN           6.0       initial-importer   5/31/2007 21:11
# 2           4.0          12.0       initial-importer    8/6/2007 23:52
# 3           NaN           NaN                    NaN   8/24/2008 16:51
# 4           NaN           NaN                    NaN   8/24/2008 17:10
# ...         ...           ...                    ...               ...
# 6027        NaN           NaN                 racoca  10/19/2011 20:43
# 6028        1.0           7.0  facebookuser770855466  10/19/2011 20:49
# 6029        NaN           2.0           jaspalsahota  10/19/2011 21:34
# 6030        NaN           NaN           trevorstuart  10/19/2011 21:44
# 6031        NaN           NaN                    NaN               NaN
#
#            updated_at        lat         lng   ROI
# 0      4/13/2013 3:29  47.606209 -122.332071  15.5
# 1     5/23/2008 23:23  34.021122 -118.396467   NaN
# 2      11/4/2013 2:09  37.562992 -122.325525   NaN
# 3      9/6/2008 14:19        NaN         NaN   NaN
# 4      9/6/2008 14:19        NaN         NaN   NaN
# ...               ...        ...         ...   ...
# 6027  10/31/2011 1:37        NaN         NaN   NaN
# 6028  8/20/2013 17:18  40.712775  -74.005973   NaN
# 6029  10/31/2011 1:39  52.486243   -1.890401   NaN
# 6030  10/31/2011 1:39        NaN         NaN   NaN
# 6031              NaN        NaN         NaN   NaN
#
# [6032 rows x 44 columns]

# %%
company.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...           9/5/2010         9/18/2013
# 1      games_video   acquired  ...                NaN               NaN
# 2      games_video   acquired  ...           2/1/2003         9/23/2011
# 3  network_hosting  operating  ...                NaN               NaN
# 4      games_video  operating  ...                NaN               NaN
#
#   milestones relationships        created_by       created_at  \
# 0        5.0          17.0  initial-importer   5/25/2007 6:51
# 1        NaN           6.0  initial-importer  5/31/2007 21:11
# 2        4.0          12.0  initial-importer   8/6/2007 23:52
# 3        NaN           NaN               NaN  8/24/2008 16:51
# 4        NaN           NaN               NaN  8/24/2008 17:10
#
#         updated_at        lat         lng   ROI
# 0   4/13/2013 3:29  47.606209 -122.332071  15.5
# 1  5/23/2008 23:23  34.021122 -118.396467   NaN
# 2   11/4/2013 2:09  37.562992 -122.325525   NaN
# 3   9/6/2008 14:19        NaN         NaN   NaN
# 4   9/6/2008 14:19        NaN         NaN   NaN
#
# [5 rows x 44 columns]

# %%
company.describe()
# Out:
#        Unnamed: 0.1      entity_id  parent_id    logo_width  logo_height  \
# count   6032.000000    6032.000000        0.0   4674.000000  4674.000000
# mean    3015.500000   59063.319297        NaN    436.389174   190.037869
# std     1741.432743   55022.875839        NaN    551.518865   313.131838
# min        0.000000       1.000000        NaN     32.000000     8.000000
# 25%     1507.750000   11638.750000        NaN    189.000000    63.000000
# 50%     3015.500000   13448.500000        NaN    257.000000    92.000000
# 75%     4523.250000  115386.250000        NaN    451.000000   181.750000
# max     6031.000000  139009.000000        NaN  10800.000000  9000.000000
#
#        investment_rounds  invested_companies  funding_rounds  \
# count         116.000000          116.000000     1253.000000
# mean            2.137931            1.913793        1.986433
# std             4.260836            3.237199        1.499939
# min             1.000000            1.000000        1.000000
# 25%             1.000000            1.000000        1.000000
# 50%             1.000000            1.000000        1.000000
# 75%             2.000000            1.000000        2.000000
# max            32.000000           24.000000       13.000000
#
#        funding_total_usd   milestones  relationships          lat  \
# count       1.058000e+03  2656.000000    4084.000000  3650.000000
# mean        2.572267e+07     1.528614       4.813173    38.239541
# std         1.872103e+08     0.883373      20.422745    14.539769
# min         2.454000e+03     1.000000       1.000000   -45.878760
# 25%         1.000000e+06     1.000000       1.000000    34.148082
# 50%         4.693212e+06     1.000000       2.000000    39.952584
# 75%         1.848848e+07     2.000000       4.000000    45.523062
# max         5.700000e+09     8.000000    1189.000000    69.649205
#
#                lng         ROI
# count  3650.000000   59.000000
# mean    -55.753640   32.278006
# std      68.025633  124.106068
# min    -157.858333    0.518135
# 25%    -117.286804    3.250547
# 50%     -77.437048    7.142857
# 75%      -0.127758   19.149283
# max     174.776236  954.548926

# %%
company.columns
# Out:
# Index(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at', 'lat', 'lng', 'ROI'],
#       dtype='object')

# %% [markdown]
# ## A. Data Cleaning
#     1. Delete irrelevant & redundant information
#     2. Remove noise or unreliable data (missing values and outliers)
#
# ### 1. Delete irrelevant and redundant information
#      a. Delete 'region','city','state_code' as they provide too much of granularity.
#      b. Delete 'id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'created_by',
#        'created_at', 'updated_at' as they are redundant.
#      c. Delete 'domain', 'homepage_url', 'twitter_username', 'logo_url', 'logo_width', 'logo_height',
#         'short_description', 'description', 'overview','tag_list', 'name', 'normalized_name', 'permalink',
#         'invested_companies' as they are irrelevant features.
#      d. Delete duplicate values if any.
#      e. Delete those which has more than 98% of null values.
#
# ### 2. Remove noise or unreliable data (missing values and outliers)
#      a. Delete instances with missing values for 'status', 'country_code', 'category_code' and 'founded_at'.
#      b. Delete outliers for 'funding_total_usd' and 'funding_rounds'.
#      c. Delete contradictory (mutually opposed or inconsistent data).

# %% [markdown]
# #### 1.a. Delete 'region','city' as they provide too much of granularity.

# %%
company.drop(['region','city'],axis=1)
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        NaN
# 1         c:10             1     Company         10        NaN
# 2        c:100             2     Company        100        NaN
# 3      c:10000             3     Company      10000        NaN
# 4      c:10001             4     Company      10001        NaN
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        NaN
# 6028  c:139006          6028     Company     139006        NaN
# 6029  c:139007          6029     Company     139007        NaN
# 6030  c:139008          6030     Company     139008        NaN
# 6031  c:139009          6031     Company     139009        NaN
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                 NaN                            NaN
#
#         category_code     status  ... first_milestone_at last_milestone_at  \
# 0                 web  operating  ...           9/5/2010         9/18/2013
# 1         games_video   acquired  ...                NaN               NaN
# 2         games_video   acquired  ...           2/1/2003         9/23/2011
# 3     network_hosting  operating  ...                NaN               NaN
# 4         games_video  operating  ...                NaN               NaN
# ...               ...        ...  ...                ...               ...
# 6027        ecommerce  operating  ...                NaN               NaN
# 6028           mobile  operating  ...           2/1/2013          2/1/2013
# 6029       consulting  operating  ...                NaN               NaN
# 6030              web  operating  ...                NaN               NaN
# 6031              NaN        NaN  ...                NaN               NaN
#
#      milestones relationships             created_by        created_at  \
# 0           5.0          17.0       initial-importer    5/25/2007 6:51
# 1           NaN           6.0       initial-importer   5/31/2007 21:11
# 2           4.0          12.0       initial-importer    8/6/2007 23:52
# 3           NaN           NaN                    NaN   8/24/2008 16:51
# 4           NaN           NaN                    NaN   8/24/2008 17:10
# ...         ...           ...                    ...               ...
# 6027        NaN           NaN                 racoca  10/19/2011 20:43
# 6028        1.0           7.0  facebookuser770855466  10/19/2011 20:49
# 6029        NaN           2.0           jaspalsahota  10/19/2011 21:34
# 6030        NaN           NaN           trevorstuart  10/19/2011 21:44
# 6031        NaN           NaN                    NaN               NaN
#
#            updated_at        lat         lng   ROI
# 0      4/13/2013 3:29  47.606209 -122.332071  15.5
# 1     5/23/2008 23:23  34.021122 -118.396467   NaN
# 2      11/4/2013 2:09  37.562992 -122.325525   NaN
# 3      9/6/2008 14:19        NaN         NaN   NaN
# 4      9/6/2008 14:19        NaN         NaN   NaN
# ...               ...        ...         ...   ...
# 6027  10/31/2011 1:37        NaN         NaN   NaN
# 6028  8/20/2013 17:18  40.712775  -74.005973   NaN
# 6029  10/31/2011 1:39  52.486243   -1.890401   NaN
# 6030  10/31/2011 1:39        NaN         NaN   NaN
# 6031              NaN        NaN         NaN   NaN
#
# [6032 rows x 42 columns]

# %% [markdown]
# #### 1.b. Delete 'id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'created_by', 'created_at', 'updated_at' as they are redundant.

# %%
c1=['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'created_by', 'created_at', 'updated_at']
company.drop(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'created_by', 'created_at', 'updated_at'],axis=1)
# Out:
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                 NaN                            NaN
#
#         category_code     status  founded_at closed_at  \
# 0                 web  operating  10/17/2005       NaN
# 1         games_video   acquired         NaN       NaN
# 2         games_video   acquired         NaN       NaN
# 3     network_hosting  operating   7/26/2008       NaN
# 4         games_video  operating   7/26/2008       NaN
# ...               ...        ...         ...       ...
# 6027        ecommerce  operating   3/11/1998       NaN
# 6028           mobile  operating    6/1/2010       NaN
# 6029       consulting  operating    1/1/2006       NaN
# 6030              web  operating    6/1/2007       NaN
# 6031              NaN        NaN         NaN       NaN
#
#                       domain                       homepage_url  \
# 0           wetpaint-inc.com            http://wetpaint-inc.com
# 1                flektor.com             http://www.flektor.com
# 2                  there.com               http://www.there.com
# 3                mywebbo.com             http://www.mywebbo.com
# 4       themoviestreamer.com        http://themoviestreamer.com
# ...                      ...                                ...
# 6027  rsalistcorporation.com  http://www.rsalistcorporation.com
# 6028          havetohave.com          http://www.havetohave.com
# 6029             vitispr.com             http://www.vitispr.com
# 6030    completeinsurance.ca    http://www.completeinsurance.ca
# 6031                     NaN                                NaN
#
#      twitter_username  ... last_funding_at  funding_rounds  funding_total_usd  \
# 0     BachelrWetpaint  ...       5/19/2008             3.0         39750000.0
# 1                 NaN  ...             NaN             NaN                NaN
# 2                 NaN  ...             NaN             NaN                NaN
# 3                 NaN  ...             NaN             NaN                NaN
# 4                 NaN  ...             NaN             NaN                NaN
# ...               ...  ...             ...             ...                ...
# 6027  rsalistservices  ...             NaN             NaN                NaN
# 6028       havetohave  ...       6/25/2012             1.0                NaN
# 6029          VitisPR  ...             NaN             NaN                NaN
# 6030   completeinsure  ...             NaN             NaN                NaN
# 6031              NaN  ...             NaN             NaN                NaN
#
#      first_milestone_at last_milestone_at milestones relationships        lat  \
# 0              9/5/2010         9/18/2013        5.0          17.0  47.606209
# 1                   NaN               NaN        NaN           6.0  34.021122
# 2              2/1/2003         9/23/2011        4.0          12.0  37.562992
# 3                   NaN               NaN        NaN           NaN        NaN
# 4                   NaN               NaN        NaN           NaN        NaN
# ...                 ...               ...        ...           ...        ...
# 6027                NaN               NaN        NaN           NaN        NaN
# 6028           2/1/2013          2/1/2013        1.0           7.0  40.712775
# 6029                NaN               NaN        NaN           2.0  52.486243
# 6030                NaN               NaN        NaN           NaN        NaN
# 6031                NaN               NaN        NaN           NaN        NaN
#
#              lng   ROI
# 0    -122.332071  15.5
# 1    -118.396467   NaN
# 2    -122.325525   NaN
# 3            NaN   NaN
# 4            NaN   NaN
# ...          ...   ...
# 6027         NaN   NaN
# 6028  -74.005973   NaN
# 6029   -1.890401   NaN
# 6030         NaN   NaN
# 6031         NaN   NaN
#
# [6032 rows x 36 columns]

# %% [markdown]
# #### 1.c. Delete 'domain', 'homepage_url', 'twitter_username', 'logo_url', 'logo_width', 'logo_height',  'short_description',    'description',  'overview','tag_list', 'name', 'normalized_name', 'permalink', 'invested_companies' as they are irrelevant features.

# %%
c2=['domain', 'homepage_url', 'twitter_username', 'logo_url', 'logo_width', 'logo_height', 'short_description', 'description', 'overview','tag_list', 'name', 'normalized_name', 'permalink', 'invested_companies' ]
company.drop(['domain', 'homepage_url', 'twitter_username', 'logo_url', 'logo_width', 'logo_height', 'short_description', 'description', 'overview','tag_list', 'name', 'normalized_name', 'permalink', 'invested_companies' ],axis=1)
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        NaN
# 1         c:10             1     Company         10        NaN
# 2        c:100             2     Company        100        NaN
# 3      c:10000             3     Company      10000        NaN
# 4      c:10001             4     Company      10001        NaN
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        NaN
# 6028  c:139006          6028     Company     139006        NaN
# 6029  c:139007          6029     Company     139007        NaN
# 6030  c:139008          6030     Company     139008        NaN
# 6031  c:139009          6031     Company     139009        NaN
#
#         category_code     status  founded_at closed_at country_code  ...  \
# 0                 web  operating  10/17/2005       NaN          USA  ...
# 1         games_video   acquired         NaN       NaN          USA  ...
# 2         games_video   acquired         NaN       NaN          USA  ...
# 3     network_hosting  operating   7/26/2008       NaN          NaN  ...
# 4         games_video  operating   7/26/2008       NaN          NaN  ...
# ...               ...        ...         ...       ...          ...  ...
# 6027        ecommerce  operating   3/11/1998       NaN          NaN  ...
# 6028           mobile  operating    6/1/2010       NaN          USA  ...
# 6029       consulting  operating    1/1/2006       NaN          GBR  ...
# 6030              web  operating    6/1/2007       NaN          NaN  ...
# 6031              NaN        NaN         NaN       NaN          NaN  ...
#
#      first_milestone_at last_milestone_at milestones relationships  \
# 0              9/5/2010         9/18/2013        5.0          17.0
# 1                   NaN               NaN        NaN           6.0
# 2              2/1/2003         9/23/2011        4.0          12.0
# 3                   NaN               NaN        NaN           NaN
# 4                   NaN               NaN        NaN           NaN
# ...                 ...               ...        ...           ...
# 6027                NaN               NaN        NaN           NaN
# 6028           2/1/2013          2/1/2013        1.0           7.0
# 6029                NaN               NaN        NaN           2.0
# 6030                NaN               NaN        NaN           NaN
# 6031                NaN               NaN        NaN           NaN
#
#                  created_by        created_at       updated_at        lat  \
# 0          initial-importer    5/25/2007 6:51   4/13/2013 3:29  47.606209
# 1          initial-importer   5/31/2007 21:11  5/23/2008 23:23  34.021122
# 2          initial-importer    8/6/2007 23:52   11/4/2013 2:09  37.562992
# 3                       NaN   8/24/2008 16:51   9/6/2008 14:19        NaN
# 4                       NaN   8/24/2008 17:10   9/6/2008 14:19        NaN
# ...                     ...               ...              ...        ...
# 6027                 racoca  10/19/2011 20:43  10/31/2011 1:37        NaN
# 6028  facebookuser770855466  10/19/2011 20:49  8/20/2013 17:18  40.712775
# 6029           jaspalsahota  10/19/2011 21:34  10/31/2011 1:39  52.486243
# 6030           trevorstuart  10/19/2011 21:44  10/31/2011 1:39        NaN
# 6031                    NaN               NaN              NaN        NaN
#
#              lng   ROI
# 0    -122.332071  15.5
# 1    -118.396467   NaN
# 2    -122.325525   NaN
# 3            NaN   NaN
# 4            NaN   NaN
# ...          ...   ...
# 6027         NaN   NaN
# 6028  -74.005973   NaN
# 6029   -1.890401   NaN
# 6030         NaN   NaN
# 6031         NaN   NaN
#
# [6032 rows x 30 columns]

# %% [markdown]
# #### 1.d. Delete duplicate values if found any.

# %%
# Delete duplicate values if found any.
company.duplicated().shape
# Out:
# (6032,)

# %%
# Let's delete all the duplicate values
company.drop_duplicates()
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        NaN
# 1         c:10             1     Company         10        NaN
# 2        c:100             2     Company        100        NaN
# 3      c:10000             3     Company      10000        NaN
# 4      c:10001             4     Company      10001        NaN
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        NaN
# 6028  c:139006          6028     Company     139006        NaN
# 6029  c:139007          6029     Company     139007        NaN
# 6030  c:139008          6030     Company     139008        NaN
# 6031  c:139009          6031     Company     139009        NaN
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                 NaN                            NaN
#
#         category_code     status  ... first_milestone_at last_milestone_at  \
# 0                 web  operating  ...           9/5/2010         9/18/2013
# 1         games_video   acquired  ...                NaN               NaN
# 2         games_video   acquired  ...           2/1/2003         9/23/2011
# 3     network_hosting  operating  ...                NaN               NaN
# 4         games_video  operating  ...                NaN               NaN
# ...               ...        ...  ...                ...               ...
# 6027        ecommerce  operating  ...                NaN               NaN
# 6028           mobile  operating  ...           2/1/2013          2/1/2013
# 6029       consulting  operating  ...                NaN               NaN
# 6030              web  operating  ...                NaN               NaN
# 6031              NaN        NaN  ...                NaN               NaN
#
#      milestones relationships             created_by        created_at  \
# 0           5.0          17.0       initial-importer    5/25/2007 6:51
# 1           NaN           6.0       initial-importer   5/31/2007 21:11
# 2           4.0          12.0       initial-importer    8/6/2007 23:52
# 3           NaN           NaN                    NaN   8/24/2008 16:51
# 4           NaN           NaN                    NaN   8/24/2008 17:10
# ...         ...           ...                    ...               ...
# 6027        NaN           NaN                 racoca  10/19/2011 20:43
# 6028        1.0           7.0  facebookuser770855466  10/19/2011 20:49
# 6029        NaN           2.0           jaspalsahota  10/19/2011 21:34
# 6030        NaN           NaN           trevorstuart  10/19/2011 21:44
# 6031        NaN           NaN                    NaN               NaN
#
#            updated_at        lat         lng   ROI
# 0      4/13/2013 3:29  47.606209 -122.332071  15.5
# 1     5/23/2008 23:23  34.021122 -118.396467   NaN
# 2      11/4/2013 2:09  37.562992 -122.325525   NaN
# 3      9/6/2008 14:19        NaN         NaN   NaN
# 4      9/6/2008 14:19        NaN         NaN   NaN
# ...               ...        ...         ...   ...
# 6027  10/31/2011 1:37        NaN         NaN   NaN
# 6028  8/20/2013 17:18  40.712775  -74.005973   NaN
# 6029  10/31/2011 1:39  52.486243   -1.890401   NaN
# 6030  10/31/2011 1:39        NaN         NaN   NaN
# 6031              NaN        NaN         NaN   NaN
#
# [6032 rows x 44 columns]

# %% [markdown]
# #### 1.e. Delete those which has more than 98% of null values.

# %%
company
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        NaN
# 1         c:10             1     Company         10        NaN
# 2        c:100             2     Company        100        NaN
# 3      c:10000             3     Company      10000        NaN
# 4      c:10001             4     Company      10001        NaN
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        NaN
# 6028  c:139006          6028     Company     139006        NaN
# 6029  c:139007          6029     Company     139007        NaN
# 6030  c:139008          6030     Company     139008        NaN
# 6031  c:139009          6031     Company     139009        NaN
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                 NaN                            NaN
#
#         category_code     status  ... first_milestone_at last_milestone_at  \
# 0                 web  operating  ...           9/5/2010         9/18/2013
# 1         games_video   acquired  ...                NaN               NaN
# 2         games_video   acquired  ...           2/1/2003         9/23/2011
# 3     network_hosting  operating  ...                NaN               NaN
# 4         games_video  operating  ...                NaN               NaN
# ...               ...        ...  ...                ...               ...
# 6027        ecommerce  operating  ...                NaN               NaN
# 6028           mobile  operating  ...           2/1/2013          2/1/2013
# 6029       consulting  operating  ...                NaN               NaN
# 6030              web  operating  ...                NaN               NaN
# 6031              NaN        NaN  ...                NaN               NaN
#
#      milestones relationships             created_by        created_at  \
# 0           5.0          17.0       initial-importer    5/25/2007 6:51
# 1           NaN           6.0       initial-importer   5/31/2007 21:11
# 2           4.0          12.0       initial-importer    8/6/2007 23:52
# 3           NaN           NaN                    NaN   8/24/2008 16:51
# 4           NaN           NaN                    NaN   8/24/2008 17:10
# ...         ...           ...                    ...               ...
# 6027        NaN           NaN                 racoca  10/19/2011 20:43
# 6028        1.0           7.0  facebookuser770855466  10/19/2011 20:49
# 6029        NaN           2.0           jaspalsahota  10/19/2011 21:34
# 6030        NaN           NaN           trevorstuart  10/19/2011 21:44
# 6031        NaN           NaN                    NaN               NaN
#
#            updated_at        lat         lng   ROI
# 0      4/13/2013 3:29  47.606209 -122.332071  15.5
# 1     5/23/2008 23:23  34.021122 -118.396467   NaN
# 2      11/4/2013 2:09  37.562992 -122.325525   NaN
# 3      9/6/2008 14:19        NaN         NaN   NaN
# 4      9/6/2008 14:19        NaN         NaN   NaN
# ...               ...        ...         ...   ...
# 6027  10/31/2011 1:37        NaN         NaN   NaN
# 6028  8/20/2013 17:18  40.712775  -74.005973   NaN
# 6029  10/31/2011 1:39  52.486243   -1.890401   NaN
# 6030  10/31/2011 1:39        NaN         NaN   NaN
# 6031              NaN        NaN         NaN   NaN
#
# [6032 rows x 44 columns]

# %%
# # Since we can see only nan values so et's check how much of ros has nan values.
company.isnull()
# Out:
#          id  Unnamed: 0.1  entity_type  entity_id  parent_id   name  \
# 0     False         False        False      False       True  False
# 1     False         False        False      False       True  False
# 2     False         False        False      False       True  False
# 3     False         False        False      False       True  False
# 4     False         False        False      False       True  False
# ...     ...           ...          ...        ...        ...    ...
# 6027  False         False        False      False       True  False
# 6028  False         False        False      False       True  False
# 6029  False         False        False      False       True  False
# 6030  False         False        False      False       True  False
# 6031  False         False        False      False       True  False
#
#       normalized_name  permalink  category_code  status  ...  \
# 0               False      False          False   False  ...
# 1               False      False          False   False  ...
# 2               False      False          False   False  ...
# 3               False      False          False   False  ...
# 4               False      False          False   False  ...
# ...               ...        ...            ...     ...  ...
# 6027            False      False          False   False  ...
# 6028            False      False          False   False  ...
# 6029            False      False          False   False  ...
# 6030            False      False          False   False  ...
# 6031             True       True           True    True  ...
#
#       first_milestone_at  last_milestone_at  milestones  relationships  \
# 0                  False              False       False          False
# 1                   True               True        True          False
# 2                  False              False       False          False
# 3                   True               True        True           True
# 4                   True               True        True           True
# ...                  ...                ...         ...            ...
# 6027                True               True        True           True
# 6028               False              False       False          False
# 6029                True               True        True          False
# 6030                True               True        True           True
# 6031                True               True        True           True
#
#       created_by  created_at  updated_at    lat    lng    ROI
# 0          False       False       False  False  False  False
# 1          False       False       False  False  False   True
# 2          False       False       False  False  False   True
# 3           True       False       False   True   True   True
# 4           True       False       False   True   True   True
# ...          ...         ...         ...    ...    ...    ...
# 6027       False       False       False   True   True   True
# 6028       False       False       False  False  False   True
# 6029       False       False       False  False  False   True
# 6030       False       False       False   True   True   True
# 6031        True        True        True   True   True   True
#
# [6032 rows x 44 columns]

# %%
# # Since we can see it has more than 96% of null values, it would not make sense to impute these data. So, lets drop it.
#Type your code here!

# %% [markdown]
# #### 2.a. Delete instances with missing values for 'status', 'country_code', 'category_code' and 'founded_at'.
#     (Since these are the type of data where adding value via imputation will create wrong pattern only)

# %%
company.status.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6027    False
# 6028    False
# 6029    False
# 6030    False
# 6031     True
# Name: status, Length: 6032, dtype: bool

# %%
company.country_code.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 6027     True
# 6028    False
# 6029    False
# 6030     True
# 6031     True
# Name: country_code, Length: 6032, dtype: bool

# %%
company.category_code.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6027    False
# 6028    False
# 6029    False
# 6030    False
# 6031     True
# Name: category_code, Length: 6032, dtype: bool

# %%
company.founded_at.isnull()
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 6027    False
# 6028    False
# 6029    False
# 6030    False
# 6031     True
# Name: founded_at, Length: 6032, dtype: bool

# %%
#Replace all Null values to 0
f1=company.fillna(value=0)
f1
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        0.0
# 1         c:10             1     Company         10        0.0
# 2        c:100             2     Company        100        0.0
# 3      c:10000             3     Company      10000        0.0
# 4      c:10001             4     Company      10001        0.0
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        0.0
# 6028  c:139006          6028     Company     139006        0.0
# 6029  c:139007          6029     Company     139007        0.0
# 6030  c:139008          6030     Company     139008        0.0
# 6031  c:139009          6031     Company     139009        0.0
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                   0                              0
#
#         category_code     status  ... first_milestone_at last_milestone_at  \
# 0                 web  operating  ...           9/5/2010         9/18/2013
# 1         games_video   acquired  ...                  0                 0
# 2         games_video   acquired  ...           2/1/2003         9/23/2011
# 3     network_hosting  operating  ...                  0                 0
# 4         games_video  operating  ...                  0                 0
# ...               ...        ...  ...                ...               ...
# 6027        ecommerce  operating  ...                  0                 0
# 6028           mobile  operating  ...           2/1/2013          2/1/2013
# 6029       consulting  operating  ...                  0                 0
# 6030              web  operating  ...                  0                 0
# 6031                0          0  ...                  0                 0
#
#      milestones relationships             created_by        created_at  \
# 0           5.0          17.0       initial-importer    5/25/2007 6:51
# 1           0.0           6.0       initial-importer   5/31/2007 21:11
# 2           4.0          12.0       initial-importer    8/6/2007 23:52
# 3           0.0           0.0                      0   8/24/2008 16:51
# 4           0.0           0.0                      0   8/24/2008 17:10
# ...         ...           ...                    ...               ...
# 6027        0.0           0.0                 racoca  10/19/2011 20:43
# 6028        1.0           7.0  facebookuser770855466  10/19/2011 20:49
# 6029        0.0           2.0           jaspalsahota  10/19/2011 21:34
# 6030        0.0           0.0           trevorstuart  10/19/2011 21:44
# 6031        0.0           0.0                      0                 0
#
#            updated_at        lat         lng   ROI
# 0      4/13/2013 3:29  47.606209 -122.332071  15.5
# 1     5/23/2008 23:23  34.021122 -118.396467   0.0
# 2      11/4/2013 2:09  37.562992 -122.325525   0.0
# 3      9/6/2008 14:19   0.000000    0.000000   0.0
# 4      9/6/2008 14:19   0.000000    0.000000   0.0
# ...               ...        ...         ...   ...
# 6027  10/31/2011 1:37   0.000000    0.000000   0.0
# 6028  8/20/2013 17:18  40.712775  -74.005973   0.0
# 6029  10/31/2011 1:39  52.486243   -1.890401   0.0
# 6030  10/31/2011 1:39   0.000000    0.000000   0.0
# 6031                0   0.000000    0.000000   0.0
#
# [6032 rows x 44 columns]

# %% [markdown]
# #### 2.b. Delete outliers for 'funding_total_usd' and 'funding_rounds'.

# %%
sns.boxplot(f1['funding_total_usd'])
plt.title("Total Funding in USD")
# Out:
# Text(0.5, 1.0, 'Total Funding in USD')

# %%
sns.boxplot(f1['funding_rounds'])
plt.title("funding rounds")
# Out:
# Text(0.5, 1.0, 'funding rounds')

# %% [markdown]
# ### Summary:
# If you can see the outlier in both 'funding_total_usd' and 'funding_rounds'. So, let's find them and drop it.
#
#     1. Find the IQR (Interquartile Range)
#     2. Find the upper and lower limit
#     3. Find outliers
#     4. Drop them
#     5. Compare the plots after trimming

# %% [markdown]
# #### 2.b.1. Find the IQR

# %%
# For funding_total_usd
q1 = company['funding_total_usd'].quantile(.25)

# For funding_rounds
q3 = company['funding_rounds'].quantile(.75)

# %% [markdown]
# #### 2.b.1. Find the Upper and Lower limit

# %%
# For funding_total_usd
#Type your code her

# For funding_rounds
#Type your code here!

# %%
# For funding_total_usd
#Type your code here!

# For funding_rounds
#Type your code here!

# %%
company

# %% [markdown]
# #### 2.c. Delete contradictory (mutually opposed or inconsistent data).

# %%
# Since we have not imputed the datasets in closed_at yet, we will check it later on.

# %% [markdown]
# # B. Date Transformation
#     It can be divided into two successive phases.
#    ## 1. Changes in original data
#         a. Convert founded_at, closed_at, first_funded_at, last_funding_at, first_milestone_at ,
#            last_milestone_at to years.
#         b. Generalize the categorical data i.e. category_code, status and category_code.
#    ## 2. Create new variables
#         a. Create new feature isClosed from closed_at and status.
#         b. Create new feature 'active_days'

# %% [markdown]
# ### 2. Create new variables¶
#     a. Create new feature isClosed from closed_at and status.
#     b. Create new feature 'active_days'

# %% [markdown]
# #### 2.a. Create new feature isClosed from closed_at and status.
#      - if the value in status is 'operating' or 'ipo', Let's put 1.
#      - Where as if the value is 'acquired' or 'closed', let's put 0.

# %%
 #Variable in Status
f1['status'].describe()
# Out:
# count          6032
# unique            5
# top       operating
# freq           5207
# Name: status, dtype: object

# %%
#Count total unique variable in a target variable
f1['status'].value_counts()
# Out:
# operating    5207
# acquired      586
# closed        189
# ipo            49
# 0               1
# Name: status, dtype: int64

# %%
#univirate analysis for some categorical columns
sns.countplot(data=f1, x='status')
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %% [markdown]
# #### 2.b. Create active_days
#      i. Replacing values:
#          -  if the value in status is 'operating' or 'ipo' in closed_at, Let's put 2021.
#          - Where as if the value is 'acquired' or 'closed', let's put 0.
#      ii. Subtract founded_date from closed_date, and calculate age in days (After calculating active days,
#          check contradictory issues we didn't check it before).
#      iii. Then, delete the closed_at column.

# %%
f1['age_closed_startup'].head()
# Out:
# 0   13073 days
# 1       0 days
# 2       0 days
# 3   14086 days
# 4   14086 days
# Name: age_closed_startup, dtype: timedelta64[ns]

# %% [markdown]
# ##### 2.b.i  Replacing the values in closed_at column
#    - if the value in status is 'operating' or 'ipo' in closed_at, Let's put 2021.
#    - Where as if the value is 'acquired' or 'closed', let's put 0.

# %% [markdown]
# #### 2.b.iii. Then, delete the closed_at column.

# %%
f1.drop(['closed_at'],axis=1)
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        0.0
# 1         c:10             1     Company         10        0.0
# 2        c:100             2     Company        100        0.0
# 3      c:10000             3     Company      10000        0.0
# 4      c:10001             4     Company      10001        0.0
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        0.0
# 6028  c:139006          6028     Company     139006        0.0
# 6029  c:139007          6029     Company     139007        0.0
# 6030  c:139008          6030     Company     139008        0.0
# 6031  c:139009          6031     Company     139009        0.0
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                   0                              0
#
#         category_code     status  ... last_milestone_at milestones  \
# 0                 web  operating  ...         9/18/2013        5.0
# 1         games_video   acquired  ...                 0        0.0
# 2         games_video   acquired  ...         9/23/2011        4.0
# 3     network_hosting  operating  ...                 0        0.0
# 4         games_video  operating  ...                 0        0.0
# ...               ...        ...  ...               ...        ...
# 6027        ecommerce  operating  ...                 0        0.0
# 6028           mobile  operating  ...          2/1/2013        1.0
# 6029       consulting  operating  ...                 0        0.0
# 6030              web  operating  ...                 0        0.0
# 6031                0          0  ...                 0        0.0
#
#      relationships             created_by        created_at       updated_at  \
# 0             17.0       initial-importer    5/25/2007 6:51   4/13/2013 3:29
# 1              6.0       initial-importer   5/31/2007 21:11  5/23/2008 23:23
# 2             12.0       initial-importer    8/6/2007 23:52   11/4/2013 2:09
# 3              0.0                      0   8/24/2008 16:51   9/6/2008 14:19
# 4              0.0                      0   8/24/2008 17:10   9/6/2008 14:19
# ...            ...                    ...               ...              ...
# 6027           0.0                 racoca  10/19/2011 20:43  10/31/2011 1:37
# 6028           7.0  facebookuser770855466  10/19/2011 20:49  8/20/2013 17:18
# 6029           2.0           jaspalsahota  10/19/2011 21:34  10/31/2011 1:39
# 6030           0.0           trevorstuart  10/19/2011 21:44  10/31/2011 1:39
# 6031           0.0                      0                 0                0
#
#             lat         lng   ROI age_closed_startup
# 0     47.606209 -122.332071  15.5         13073 days
# 1     34.021122 -118.396467   0.0             0 days
# 2     37.562992 -122.325525   0.0             0 days
# 3      0.000000    0.000000   0.0         14086 days
# 4      0.000000    0.000000   0.0         14086 days
# ...         ...         ...   ...                ...
# 6027   0.000000    0.000000   0.0         10296 days
# 6028  40.712775  -74.005973   0.0         14761 days
# 6029  52.486243   -1.890401   0.0         13149 days
# 6030   0.000000    0.000000   0.0         13665 days
# 6031   0.000000    0.000000   0.0             0 days
#
# [6032 rows x 44 columns]

# %% [markdown]
# ### Let's work on target variabe now.

# %%
#Type your code here!

# %%
#Type your code here!

# %%
#Type your code here!

# %%
#Type your code here!

# %% [markdown]
# ### Remove the null vaues with the mean value in 'Numerical Data'

# %%
company
# Out:
#             id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0          c:1             0     Company          1        NaN
# 1         c:10             1     Company         10        NaN
# 2        c:100             2     Company        100        NaN
# 3      c:10000             3     Company      10000        NaN
# 4      c:10001             4     Company      10001        NaN
# ...        ...           ...         ...        ...        ...
# 6027  c:139004          6027     Company     139004        NaN
# 6028  c:139006          6028     Company     139006        NaN
# 6029  c:139007          6029     Company     139007        NaN
# 6030  c:139008          6030     Company     139008        NaN
# 6031  c:139009          6031     Company     139009        NaN
#
#                       name     normalized_name                      permalink  \
# 0                 Wetpaint            wetpaint              /company/wetpaint
# 1                  Flektor             flektor               /company/flektor
# 2                    There               there                 /company/there
# 3                  MYWEBBO             mywebbo               /company/mywebbo
# 4       THE Movie Streamer  the movie streamer    /company/the-movie-streamer
# ...                    ...                 ...                            ...
# 6027  RSA List Corporation            rsa list  /company/rsa-list-corporation
# 6028          Have to Have        have to have          /company/have-to-have
# 6029              Vitis PR            vitis pr              /company/vitis-pr
# 6030    Complete Insurance  complete insurance    /company/complete-insurance
# 6031            My Yard So                 NaN                            NaN
#
#         category_code     status  ... first_milestone_at last_milestone_at  \
# 0                 web  operating  ...           9/5/2010         9/18/2013
# 1         games_video   acquired  ...                NaN               NaN
# 2         games_video   acquired  ...           2/1/2003         9/23/2011
# 3     network_hosting  operating  ...                NaN               NaN
# 4         games_video  operating  ...                NaN               NaN
# ...               ...        ...  ...                ...               ...
# 6027        ecommerce  operating  ...                NaN               NaN
# 6028           mobile  operating  ...           2/1/2013          2/1/2013
# 6029       consulting  operating  ...                NaN               NaN
# 6030              web  operating  ...                NaN               NaN
# 6031              NaN        NaN  ...                NaN               NaN
#
#      milestones relationships             created_by        created_at  \
# 0           5.0          17.0       initial-importer    5/25/2007 6:51
# 1           NaN           6.0       initial-importer   5/31/2007 21:11
# 2           4.0          12.0       initial-importer    8/6/2007 23:52
# 3           NaN           NaN                    NaN   8/24/2008 16:51
# 4           NaN           NaN                    NaN   8/24/2008 17:10
# ...         ...           ...                    ...               ...
# 6027        NaN           NaN                 racoca  10/19/2011 20:43
# 6028        1.0           7.0  facebookuser770855466  10/19/2011 20:49
# 6029        NaN           2.0           jaspalsahota  10/19/2011 21:34
# 6030        NaN           NaN           trevorstuart  10/19/2011 21:44
# 6031        NaN           NaN                    NaN               NaN
#
#            updated_at        lat         lng   ROI
# 0      4/13/2013 3:29  47.606209 -122.332071  15.5
# 1     5/23/2008 23:23  34.021122 -118.396467   NaN
# 2      11/4/2013 2:09  37.562992 -122.325525   NaN
# 3      9/6/2008 14:19        NaN         NaN   NaN
# 4      9/6/2008 14:19        NaN         NaN   NaN
# ...               ...        ...         ...   ...
# 6027  10/31/2011 1:37        NaN         NaN   NaN
# 6028  8/20/2013 17:18  40.712775  -74.005973   NaN
# 6029  10/31/2011 1:39  52.486243   -1.890401   NaN
# 6030  10/31/2011 1:39        NaN         NaN   NaN
# 6031              NaN        NaN         NaN   NaN
#
# [6032 rows x 44 columns]

# %%
# Final null check on data
company.isnull()
# Out:
#          id  Unnamed: 0.1  entity_type  entity_id  parent_id   name  \
# 0     False         False        False      False       True  False
# 1     False         False        False      False       True  False
# 2     False         False        False      False       True  False
# 3     False         False        False      False       True  False
# 4     False         False        False      False       True  False
# ...     ...           ...          ...        ...        ...    ...
# 6027  False         False        False      False       True  False
# 6028  False         False        False      False       True  False
# 6029  False         False        False      False       True  False
# 6030  False         False        False      False       True  False
# 6031  False         False        False      False       True  False
#
#       normalized_name  permalink  category_code  status  ...  \
# 0               False      False          False   False  ...
# 1               False      False          False   False  ...
# 2               False      False          False   False  ...
# 3               False      False          False   False  ...
# 4               False      False          False   False  ...
# ...               ...        ...            ...     ...  ...
# 6027            False      False          False   False  ...
# 6028            False      False          False   False  ...
# 6029            False      False          False   False  ...
# 6030            False      False          False   False  ...
# 6031             True       True           True    True  ...
#
#       first_milestone_at  last_milestone_at  milestones  relationships  \
# 0                  False              False       False          False
# 1                   True               True        True          False
# 2                  False              False       False          False
# 3                   True               True        True           True
# 4                   True               True        True           True
# ...                  ...                ...         ...            ...
# 6027                True               True        True           True
# 6028               False              False       False          False
# 6029                True               True        True          False
# 6030                True               True        True           True
# 6031                True               True        True           True
#
#       created_by  created_at  updated_at    lat    lng    ROI
# 0          False       False       False  False  False  False
# 1          False       False       False  False  False   True
# 2          False       False       False  False  False   True
# 3           True       False       False   True   True   True
# 4           True       False       False   True   True   True
# ...          ...         ...         ...    ...    ...    ...
# 6027       False       False       False   True   True   True
# 6028       False       False       False  False  False   True
# 6029       False       False       False  False  False   True
# 6030       False       False       False   True   True   True
# 6031        True        True        True   True   True   True
#
# [6032 rows x 44 columns]

# %%
#Finally Save cleaned Data.
company.to_csv('raw_data.csv', index=False)
